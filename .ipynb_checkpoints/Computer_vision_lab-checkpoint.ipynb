# %% [markdown]
# **COMPUTER VISION LAB**

# %% [markdown]
# **Activity 1:** Find ethically challenged issues with computer vision.
#
# **Name of article:** The ethical questions that haunt facial-recognition research by Richard Van Noorden
#
# **Link:** https://www.nature.com/articles/d41586-020-03187-3
#
# **Commentary:** Nature magazine published an article (linked above) discussing the ethical issues that may arise due to facial recognition research. Although facial recognition reserch can do much good for society it is crucial that reserchers recognize that a technology that can remotely identify or classify people without their knowledge is dangerous — and should try to resist it being used to control or criminalize people. Nature conducted a well rounded survey to identify what researchers and the public tgought about this controversial issue. When asked for their opinions on studies that apply facial-recognition methods to recognize or predict personal characteristics (such as gender, sexual identity, age or ethnicity) from appearance, around two-thirds said that such studies should be done only with the informed consent of those whose faces were used, or after discussion with representatives of groups that might be affected. The researchers’ dilemma is that it’s hard to see how they can train accurate facial-recognition algorithms without vast data sets of photos. Therefore, facial-recognition technology can be extremely beneficial to society, but it could also create negative situations for minorities and people that do not look like the candidates used for testing.

# %% [markdown]
# **Activity 2:** Use https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide
#
# **Caption Provided:** A zebra walking on a road with two cars crashing.
#
# **Commentary:** The image generation tool was able to portray a zebra, even though its body outline is not fully correct as it doesn not seems to have a head and more legs than it should. The cars crashing is also not clear, they do not seem to be crashing and it is even hard to identigy them as cars. The image genrator was able to provide a base outline of both the zebra and cars, but it is pixelated and not fully clear what is happening in the image.
#
# **Image Provided:**

# %%
import matplotlib as plt
# %matplotlib inline
from IPython.display import Image
Image('Zebra_Car.png')

# %% [markdown]
# **Activity 3:** read this blog article and give a summary of process.
#
# **Link:** https://thedatafrog.com/en/articles/dogs-vs-cats/

# %% [markdown]
# - The coder used indices for the bad images I could find in each category, and removed them from dataset.
# - Implement a small function to clean up the dataset of cartoons and other images that do not correspond to cats or dogs.
# - The ImageDataGenerator automatically produced a label for each image depending on the directory in which it was found. One-hot encoding is used for the labels.
# - To validate the dataset labels, we want to check that, for a few batches, the labels are correctly set. So we need a function that can plot a fairly large number of images and label them.
# - To make sure that overfitting does not occur, we will evaluate the performance of the network on a validation dataset , disjoint from the training dataset.
# - Created a deep convolutional neural networks to classidy images from cat to dog.
# - Have two neurons in the last softmax layer instead of 10, as we now have two categories.
# - The input_shape of the first layer has to match the shape given to the generator.
# - The dropout rate was increased from 0.4 to 0.9 to help reduce overfitting.
